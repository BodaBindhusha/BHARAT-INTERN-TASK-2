# %% [markdown]
# <a href="https://colab.research.google.com/github/BodaBindhusha/BHARAT-INTERN-TASK-2/blob/main/DL_EXP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#9921005004
#B.BINDHUSHA
import re
import json
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot') # setting the style to ggplot
import urllib.request

url = 'https://raw.githubusercontent.com/MonashDataFluency/python-web-scraping/master/data/infoboxes.json'

urllib.request.urlretrieve(url, 'infoboxes.json')
with open('infoboxes.json', 'r') as file:
  wiki_data = json.load(file)
wiki_data[0]
for i in range(0,3):
  print(wiki_data[i]['products'])
  print('\n')
regex = re.compile(r'[\w\s-]+')
rogue_words = ['unbulleted list', 'hlist', 'flat list', 'flatlist', 'plainlist', 's', 'br', '']
products = []
data = []
for x in wiki_data:
  product = x['products'].lower() # get products and lowercase them
# replace 'and' with '|' and ']]' with empty string
  product = product.replace(' and ', '|').replace(']]', '')
  product = regex.findall(product) # extract all alphanumeric occurences
  product = [p.strip() for p in product] # get rid of leading or trailing whitespace
# filter rogue words and de-duplicate
  product = list(set([p for p in product if p not in rogue_words]))
# add to data
  data.append({
       'wiki_title' : x['company_name'],
       'product' : ', '.join(product)
       })
  products.extend(product)
print(products)
def create_wordcloud(items, stopwords=[]):
    text = ' '.join(items)
    wordcloud = WordCloud(width=1600,
                height=800,
                margin=0,
                stopwords=stopwords
                ).generate(text) # optionally we can set max_words=20
    plt.figure( figsize=(20,10)) # set the final figure size
    plt.imshow(wordcloud, interpolation="bilinear") # pass the image and setinterpolation type
    plt.axis("off") # turn all axes off
    plt.tight_layout(pad=0) # no padding
    plt.show() # display plot
create_wordcloud(products)
for i in range(0,5):
  print(wiki_data[i]['industry'])
industries = []
for i, x in enumerate(wiki_data):
  industry = x['industry'].lower() # get industries and lowercase
# replace 'and' with '|' and ']]' with empty space
  industry = industry.replace(' and ', '|').replace(']]', '')
  # extract all industries
  industry = regex.findall(industry)
# strip trailing and leading spaces
  industry = [i.strip() for i in industry]
# filter rogue words and de-duplicate
  industry = list(set([i for i in industry if i not in rogue_words]))
# add to data
  data[i]['industry'] = ', '.join(industry)
# add to list of industries
  industries.extend(industry)
print(industries)
create_wordcloud(industries, ['industry'])
for i in range(0,len(wiki_data)):
   print(wiki_data[i]['assets'])
regex1 = re.compile('([\d\.]+)')
regex2 = re.compile('(billion|trillion)')
assets = []
for i, x in enumerate(wiki_data):
  y = x['assets'] # get assets
  z = regex1.findall(y)[0] # extract assets
  unit = regex2.findall(y)[0] # extract the unit
  asset = float(z) # convert to the numeric
  data[i]['assets'] = str(asset) + ' ' + unit # add to data
# add to list of assets
  assets.append({'company' : x['company_name'], 'value' : asset, 'unit' : unit})
  assets
for i, asset in enumerate(assets):
  if asset['unit'] == 'trillion': # if unit is in trillion
    assets[i]['value'] = asset['value'] * 1000 # convert trillion to billion
    assets[i]['unit'] = 'billion'
df_assets = pd.DataFrame(assets)
df_assets
# Out:
# {{hlist|Electronics|Movies and music|Home and furniture|Home improvement|Clothing|Footwear|Jewelry|Toys|Health and beauty|Pet supplies|Sporting goods and fitness|Auto|Photo finishing|Craft supplies|Party supplies|Grocery}}
#
#
# {{Unbulleted list
#   | [[Crude oil]]
#   | [[Oil products]]
#   | [[Natural gas]]
#   | [[Petrochemical]]s
#   | [[Power generation]]}}
#
#
# [[Investment|Diversified investments]], [[Insurance#Types|Property & casualty insurance]], [[Public utility|Utilities]], [[Restaurants]], [[Food processing]], [[Aerospace]], [[Toys]], [[Mass media|Media]], [[Automotive industry|Automotive]], [[Sports equipment|Sporting goods]], [[Final good|Consumer products]], [[Internet]], [[Real estate]]
#
#
# ['beauty', 'furniture', 'fitness', 'movies', 'photo finishing', 'home improvement', 'health', 'clothing', 'pet supplies', 'footwear', 'jewelry', 'music', 'craft supplies', 'party supplies', 'sporting goods', 'home', 'auto', 'electronics', 'toys', 'grocery', 'oil products', 'power generation', 'natural gas', 'crude oil', 'petrochemicals', 'investment', 'casualty insurance', 'internet', 'media', 'automotive', 'types', 'final good', 'food processing', 'automotive industry', 'property', 'consumer products', 'insurance', 'public utility', 'aerospace', 'mass media', 'real estate', 'utilities', 'restaurants', 'sporting goods', 'diversified investments', 'sports equipment', 'toys', 'iwork', 'siri', 'final cut pro', 'ipod', 'ipados', 'application', 'iphone', 'watchos', 'logic pro', 'ios', 'apple watch', 'ilife', 'homepod', 'macintosh', 'tvos', 'macos', 'ipad', 'garageband', 'apple tv', 'shazam', 'specialized care services', 'ingenix', 'services', 'health care', 'economics', 'uniprise', 'service', 'health care services', 'medical technology', 'pharmaceuticals', 'amazon kindle', 'amazon fire tv', 'amazon fire os', 'amazon fire', 'amazon fire tablet', 'fire os', 'amazon echo', 'fixed-line telephones', 'internet services', 'ott services', 'landline', 'video games', 'television production', 'cable television', 'pay television', 'internet service provider', 'news agency', 'film production', 'network security', 'publishing', 'broadband', 'sports management', 'mobile phone', 'home security', 'mobile telephones', 'filmmaking', 'over-the-top media services', 'satellite television', 'iptv', 'podcasts', 'digital television', 'automobiles', 'automobile parts', 'commercial vehicles', 'car', 'automobiles', 'car', 'luxury vehicles', 'suvs', 'commercial vehicles', 'list of auto parts', 'pickup trucks', 'automotive parts', 'luxury car', 'commercial vehicle', 'pharmacy services', 'pharmaceuticals', 'see chevron products', 'petroleum', 'marketing brands', 'natural gas', 'other', 'petrochemicals', 'pharmaceutical products', 'medical', 'services', 'mobile phone', 'internet of things', 'landline', 'digital media', 'telematics', 'cable television', 'broadband', 'iptv', 'digital television', 'internet', 'other specialty', 'superstore', 'supercenter', 'supermarket', 'electrical distribution', 'aircraft engines', 'electric motors', 'software', 'health care', 'electric power distribution', 'lighting', 'wind turbines', 'finance', 'energy', 'drug store', 'pharmacy', 'investment', 'financial analysis', 'private banking', 'prime brokerage', 'broker services', 'credit derivative trading', 'custodian banking', 'hedge funds', 'portfolios', 'digital banking', 'commodity market', 'financial markets', 'pension funds', 'alternative financial services', 'futures exchange', 'private equity', 'investment capital', 'money market trading', 'subprime lending', 'wealth management', 'mortgage brokering', 'investment management', 'mobile banking', 'wholesale funding', 'wholesale mortgage lending', 'foreign exchange market', 'securities lending', 'mortgage-backed security', 'brokerage', 'security services', 'wholesale mortgage lenders', 'loan servicing', 'venture capital', 'retail', 'mutual funds', 'exchange-traded funds', 'wire transfers', 'asset allocation', 'capital market services', 'currency exchange', 'mortgage', 'insurance', 'security', 'underwriting', 'financial capital', 'estate planning', 'trustee services', 'investment banking', 'mortgage loans', 'remittance', 'stock trading', 'backed securities', 'bond', 'commercial banking', 'index funds', 'retail banking', 'asset management', 'treasury services', 'credit cards', 'bond trading', 'commodities trading', 'information processing', 'stock trader', 'collateralized debt obligations', 'merchant services', 'mortgage brokers', 'institutional investor', 'risk management', 'american depositary receipts', 'institutional investing', 'debt settlement', 'portfolio', 'credit default swap', 'finance']
# [[Retail]]
# [[Energy industry|Energy]]: [[Oil and gas industry|Oil and gas]]
# [[Conglomerate (company)|Conglomerate]]
# {{Unbulleted list | [[Computer hardware]] | [[Computer software]] | [[Consumer electronics]] | [[Cloud computing]] | [[Digital distribution]] | [[Fabless manufacturing|Fabless silicon design]] | [[Semiconductors]] | [[Financial technology]] | [[Artificial intelligence]]}}
# [[Managed health care]]
# ['retail', 'gas', 'oil', 'energy', 'energy industry', 'gas industry', 'company', 'conglomerate', 'semiconductors', 'financial technology', 'cloud computing', 'artificial intelligence', 'fabless manufacturing', 'fabless silicon design', 'digital distribution', 'computer hardware', 'consumer electronics', 'computer software', 'managed health care', 'healthcare', 'health care', 'retail', 'cloud computing', 'artificial intelligence', 'digital distribution', 'e-commerce', 'consumer electronics', 'grocery stores', 'telecommunications', 'telecommunications industry', 'entertainment', 'mass media', 'technology', 'technology company', 'automotive', 'automotive industry', 'automotive', 'automotive industry', 'pharmaceutical', 'gas', 'oil', 'gas industry', 'pharmaceuticals', 'retail', 'telecommunications', 'mass media', 'telecommunications industry', 'retail', 'company', 'conglomerate', 'pharmaceutical', 'retail', 'banking', 'financial services']
# {{increase}} {{US$|219.295 billion}} (2019)
# {{Nowrap|Decrease| |US$|346.2 billion|ref| name="201310K"}} {{Decrease}} {{US$|346.2 billion}}
# {{increase}} US$707.8 billion (2018)
# {{Decrease}} {{US$|338.516&nbsp;billion}}
# {{increase}} $173.889 billion (2019)
# {{nowrap|increase| |US$|60.381 billion| |small|(2018)|ref| name=FY}} {{increase}} {{US$|60.381 billion}} {{small|(2018)}}
# {{increase}} {{US$|196.456 billion}}
# {{decrease}} {{US$|162.648 billion}}
# {{increase}} {{US$|link|=|yes}} 531 billion     (2018)
# {{increase}} US$227.339 billion {{small|(2018)}}
# {{decrease}} {{US$|256.54 billion}} {{small|(2018)}}
# {{increase}} {{US$|37.66 billion}} (2018)
# {{decrease}} {{US$|253.9 billion}} {{small|(2018)}}
# {{increase}} US$39.95 billion {{small|(2018)}}
# {{increase}} US$45.40 billion
# {{increase}} {{US$|264.82 billion}}
# {{increase}} {{US$|38.11 billion}} (2019)
# {{nowrap|Decrease| US$ 309.129 billion |small|(2018)}} {{Decrease}} US$ 309.129 billion {{small|(2018)}}
# {{decrease}} {{US$|67.59 billion}}
# {{increase}} [[United States dollar|US$]]2.687 [[trillion]]
#                      company     value     unit
# 0                    Walmart   219.295  billion
# 1                 ExxonMobil   346.200  billion
# 2         Berkshire Hathaway   707.800  billion
# 3                 Apple Inc.   338.516  billion
# 4         UnitedHealth Group   173.889  billion
# 5       McKesson Corporation    60.381  billion
# 6                 CVS Health   196.456  billion
# 7           Amazon (company)   162.648  billion
# 8                       AT&T   531.000  billion
# 9             General Motors   227.339  billion
# 10        Ford Motor Company   256.540  billion
# 11         AmerisourceBergen    37.660  billion
# 12       Chevron Corporation   253.900  billion
# 13           Cardinal Health    39.950  billion
# 14                    Costco    45.400  billion
# 15    Verizon Communications   264.820  billion
# 16                    Kroger    38.110  billion
# 17          General Electric   309.129  billion
# 18  Walgreens Boots Alliance    67.590  billion
# 19            JPMorgan Chase  2687.000  billion
